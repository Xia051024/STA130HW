# %%
#1.
import numpy as np
all_door_options = (1,2,3)  # tuple
#This imports the NumPy library and creates a tuple all_door_options representing the three doors.
my_door_choice = 1  # 1,2,3
#This initializes the player's initial door choice to door 1 (this is arbitrary for the simulation).
i_won = 0
reps = 100000
#i_won counts how many times the player wins the game.
#reps is set to 100,000, which is the number of simulations to be run
for i in range(reps):
#This starts a loop to run the simulation reps (100,000) times.
    secret_winning_door = np.random.choice(all_door_options)
#Randomly selects the secret winning door (1, 2, or 3).
    all_door_options_list = list(all_door_options)
#Converts the tuple of door options into a list for easy manipulation.
    all_door_options_list.remove(secret_winning_door)
#Removes the secret winning door from the list of available doors, leaving only the losing doors (the goats).
    try:
        all_door_options_list.remove(my_door_choice)
    except:
        pass
#Tries to remove the player's original door choice from the list of remaining doors. If the player’s choice was already removed (because it was the winning door), the try/except block avoids errors.
    goat_door_reveal = np.random.choice(all_door_options_list)
    all_door_options_list.remove(goat_door_reveal)
#The host reveals one of the goat doors randomly, and that door is removed from the list of remaining options.
    if secret_winning_door != my_door_choice:
        all_door_options_list.append(secret_winning_door)
#If the player's original choice was not the winning door, the winning door is added back to the list of remaining doors.
    my_door_choice = all_door_options_list[0]
#The player switches to the remaining door (this is the "switch" strategy).
    if my_door_choice == secret_winning_door:
        i_won += 1
#If the player’s new door choice (after switching) matches the secret winning door, they win, and i_won is incremented by 1.
i_won/reps
#After all simulations, the code outputs the ratio of wins to total simulations, which shows the probability of winning by switching.

# %%
#2.
import numpy as np

reps = 100000  # Number of repetitions
i_won = 0  # Counter for wins when switching doors

for _ in range(reps):
    # Randomly choose the winning door and the player's initial choice
    winning_door = np.random.randint(1, 4)
    my_initial_choice = np.random.randint(1, 4)

    # Simulate switching the door: if the player's initial choice was correct, switch to a wrong door (lose)
    # If the initial choice was wrong, switch to the correct door (win)
    if my_initial_choice != winning_door:
        i_won += 1  # Switching leads to a win when the initial choice is wrong

# Calculate the win percentage when switching
win_percentage = i_won / reps
win_percentage
# Out:
# 0.66641

# %% [markdown]
# 2 (continue)
# #Explanation:
# #This code simplifies the process by directly comparing the player's initial choice with the winning door and counting wins when the player switches. It maintains the logic of the Monty Hall problem without the need for removing doors or revealing goats explicitly.
#
# #For me, I think this simplified code is better to understand. First, it has less length than the first code. By using random.randint(), the code can randomly generate the number from 1 to 3, which will be repeated by range().However, for the previous code, those lists need to use random.choice to pick numbers from all_door_options list, which is more complicated to understand.
# Also, the symplified code does not need to delete or remove any lists generated. It directly uses "if" to clarify which pairs of numbers to be conted as i_won.

# %%
#3.
import numpy as np #imports np library

reps = 100000  # Number of repetitions
i_won = 0  # Counter for wins when switching doors

for _ in range(reps):
    # Randomly choose the winning door and the player's initial choice
    winning_door = np.random.randint(1, 4)
    my_initial_choice = np.random.randint(1, 4) #randomly pick numbers from 1 to 3
    
    # Simulate switching the door: if the player's initial choice was correct, switch to a wrong door (lose)
    # If the initial choice was wrong, switch to the correct door (win)
    if my_initial_choice != winning_door:
        i_won += 1  # Switching leads to a win when the initial choice is wrong

# Calculate the win percentage when switching
win_percentage = i_won / reps
win_percentage #print

#chat history :https://chatgpt.com/share/66eb6a6d-5850-8008-943c-e3b932bfcbc4

# %%
#4.
#This code snippet is setting up a basic Markov model to analyze and generate sequences of words. Here’s what each part does:
#Initialization:
word_used = dict()  # Dictionary to count occurrences of each word
next_word = dict()  # Dictionary to keep track of the frequency of each word following another word
#Loop through the list of words:
for i, word in enumerate(words[:-1]):
#enumerate(words[:-1]) iterates through the list of words, but stops at the second-to-last word (words[:-1]) to ensure you can check the next word (words[i+1]).
#Update word_used dictionary:
    if word in word_used:
        word_used[word] += 1
    else:
        word_used[word] = 1
        next_word[word] = {}
#Checks if the current word (word) is already in word_used.
#If it is, increments its count.
#If it’s not, initializes its count to 1 and sets up an empty dictionary for tracking the next words that follow it in next_word.
#Update next_word dictionary:
    if words[i+1] in next_word[word]:
        next_word[word][words[i+1]] += 1
    else:
        next_word[word][words[i+1]] = 1

#Checks if the next word (words[i+1]) is already in the dictionary of words that follow the current word (next_word[word]).
#If it is, increments the count for that next word.
#If it’s not, initializes its count to 1.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       5 next_word = dict()  # Dictionary to keep track of the frequency of each word following another word
#       6 #Loop through the list of words:
# ----> 7 for i, word in enumerate(words[:-1]):
#       8 #enumerate(words[:-1]) iterates through the list of words, but stops at the second-to-last word (words[:-1]) to ensure you can check the next word (words[i+1]).
#       9 #Update word_used dictionary:
#      10     if word in word_used:
#      11         word_used[word] += 1
#
# NameError: name 'words' is not defined

# %% [markdown]
# 4 (CONTINUE) One application I would think of is to create behaviors for non-player characters (NPCs) based on the game state and previous actions.
# chat history: https://chatgpt.com/share/66eb7693-6f90-8008-b647-ef950293106e

# %% [markdown]
# 5.
# 1)
# For extension 1:
# The extension introduces a more complex Markov model by considering pairs of words (bigrams) instead of single words. Here's a quick rundown:
#
# 1. **`word_used2`**: This dictionary counts occurrences of bigrams (pairs of consecutive words) in your text.
#
# 2. **`next_word2`**: This nested dictionary tracks how often each bigram is followed by a third word.
#
# In this model:
# - `word_used2[word+' '+words[i+1]]` counts occurrences of the bigram formed by `word` and `words[i+1]`.
# - `next_word2[word+' '+words[i+1]][words[i+2]]` counts how often the bigram `word+' '+words[i+1]` is followed by the word `words[i+2]`.
#
# For extension 2:
# This extension adds a character-based dimension to your Markovian chatbot model. Here's a breakdown of what's happening:
#
# 1. **`characters`**: This `Counter` object counts occurrences of each character in the `avatar.character` column after normalizing the text (converting to uppercase and replacing spaces).
#
# 2. **`nested_dict`**: This lambda function creates nested `defaultdict` objects, allowing you to build a multi-level dictionary structure easily.
#
# 3. **`word_used2C`**: This dictionary tracks the count of bigrams (pairs of words) for each character.
#
# 4. **`next_word2C`**: This dictionary tracks how often each bigram is followed by a third word, with the distinction made by character.
#
# **Explanation of the loop:**
# - It iterates through the `words` list (excluding the last two elements to avoid index errors).
# - `character` is set based on the current word if it exists in `characters`.
# - Updates `word_used2C` to count occurrences of each bigram specific to a character.
# - Updates `next_word2C` to count how often a bigram is followed by a third word, specific to a character.
#
# This approach allows you to model the language differently for each character in your dataset, providing a more nuanced and potentially richer chatbot output.
#
# chat history: https://chatgpt.com/share/66eb7693-6f90-8008-b647-ef950293106e
#
# 2) More detailed explanation:
# word_used2: This dictionary counts occurrences of bigrams (two consecutive words). For example, in the sentence "the quick brown fox":
# word_used2["the quick"] will count how many times the bigram "the quick" appears.
# If "the quick" appears twice, then word_used2["the quick"] will be 2.
# next_word2: This nested dictionary tracks how often each bigram is followed by a third word. For example:
# In "the quick brown fox", next_word2["the quick"]["brown"] will count how many times "the quick" is followed by "brown".
# If "the quick brown" appears once after "the quick", then next_word2["the quick"]["brown"] will be 1.
# Example Usage:
# Given the text "the quick brown fox jumps", the bigrams are "the quick", "quick brown", and "brown fox".
# word_used2 will store counts for "the quick", "quick brown", and "brown fox".
# next_word2 will store counts of what follows each bigram. For instance, it will have a count of how often "the quick" is followed by "brown".
#
#
# characters: Counts occurrences of each character in the avatar.character column after normalizing the text. This helps identify different characters in the dialogues.
# word_used2C: A nested dictionary where:
# The top level key is a character.
# The second level key is a bigram (two consecutive words).
# The value is the count of how often that bigram appears in the dialogue of that character.
# next_word2C: A nested dictionary where:
# The top level key is a character.
# The second level key is a bigram.
# The third level key is a word that follows the bigram.
# The value is the count of how often the word follows the bigram in that character’s dialogue.
# Example Usage:
# If "character1" says "the quick brown fox", then:
# word_used2C["character1"]["the quick"] will count how many times "the quick" appears in "character1"'s dialogues.
# next_word2C["character1"]["the quick"]["brown"] will count how often "the quick" is followed by "brown" in "character1"'s dialogues.
#
# chat summary: https://chatgpt.com/share/66eb7693-6f90-8008-b647-ef950293106e
#
# 3)
#
# 1. **Data Preparation**: `characters` is a `Counter` object counting occurrences of characters in your dataset, formatted in a specific way.
#
# 2. **Data Structures**:
#    - `word_used2C`: Keeps track of how often each word pair is used by each character.
#    - `next_word2C`: Tracks the frequency of the word that follows a given word pair for each character.
#
# 3. **Processing Loop**: For each word in the dataset (up to the third-to-last word), you:
#    - Identify the current character.
#    - Update `word_used2C` to count occurrences of each word pair.
#    - Update `next_word2C` to count occurrences of the word following a given word pair.
#
# Here’s a brief walkthrough of what’s happening in the code:
#
# 1. **Character Count Initialization**:
#    ```python
#    characters = Counter("\n"+ avatar.character.str.upper().str.replace(' ','.')+":")
#    ```
#
# 2. **Nested Dictionary Initialization**:
#    ```python
#    nested_dict = lambda: defaultdict(nested_dict)
#    ```
#
# 3. **Data Structures Creation**:
#    ```python
#    word_used2C = nested_dict()
#    next_word2C = nested_dict()
#    ```
#
# 4. **Processing**:
#    ```python
#    for i, word in enumerate(words[:-2]):
#        if word in characters:
#            character = word
#
#        # Update word_used2C
#        if character not in word_used2C:
#            word_used2C[character] = dict()
#        if word + ' ' + words[i+1] not in word_used2C[character]:
#            word_used2C[character][word + ' ' + words[i+1]] = 0
#        word_used2C[character][word + ' ' + words[i+1]] += 1
#
#        # Update next_word2C
#        if character not in next_word2C:
#            next_word2C[character] = dict()
#        if word + ' ' + words[i+1] not in next_word2C[character]:
#            next_word2C[character][word + ' ' + words[i+1]] = dict()
#        if words[i+2] not in next_word2C[character][word + ' ' + words[i+1]]:
#            next_word2C[character][word + ' ' + words[i+1]][words[i+2]] = 0
#        next_word2C[character][word + ' ' + words[i+1]][words[i+2]] += 1
#    ```
#
# **Suggestions:**
# - Ensure `words` is defined and contains the text data split into tokens.
# - Handle cases where `words` might be shorter than expected, causing index errors.
#
# chat summary: https://chatgpt.com/share/66eb78f3-d320-8008-a7a8-a6c4674a0f18

# %% [markdown]
# 6. Report on your experience interacting with ChatBots to understand the Monte Hall problem and "Markovian ChatBot" code
#
# Discuss how quickly the ChatBot was able to be helpful for each of the above questions, and if so, how?
# I think ChatBot gives me a quite accurate answer to solve my problem. It might sometimes be too general, such as giving me conclusion of the code which might not be so helpful. It does point out all the function in my code and show me how these functions works. However,sometimes the explanation might be too general so I need to narrow down and keep asking.
#
# Discuss whether or not interacting with ChatBot to try to figure things out was frustrating or unhelpful, and if so, how?
# I think ChatBot is helpful. As I just ask it about the extension of code, it still answers me even though I do not give it any background information or the non-extented code. It overwhelmingly answered my questions very accurately and wrote or modified the code accordingly, with some explanation. But it often uses words I do not understand in the explanation. Perhaps it is because I am a beginner of python. This could also be attributed to the fact that it is not so concenient for beginners, as I need to ask more and narrow down my questions.
#
# Based on your experiences to date (e.g., including using ChatBots to troubleshoot coding errors in the previous homework), provide an overall assessment evaluating the usefulness of ChatBots as tools to help you understand code
# I think chatgpt is successful in helping me understand the code. I'm just a beginner, and I've learned much through it. Usually for functions that I haven't learned, I just type them into chat. Chat would give me many examples and the usage of the function.  The explanation is very clear and readable. Even the examples it gives are progressively more difficult, which suits me very well.

# %% [markdown]
# #7. I think chatgpt has helped me a lot in learning python. But in terms of generating code, I don't think it's mature enough. If I don't give it enough preconditions or framework to make it learn more about what exactly I want, it might not generate a code that is demanded. It might report errors sometimes. However, up to now, chat has been so helpful to help me learn coding and stats. I recognize its absolute superiority in terms of its huge knowledge base.

# %% [markdown]
# 8.1
# Mastering skills in learning and adaptability, communication, coding, and statistics can significantly enhance my career opportunities. These abilities not only make me versatile and capable of handling diverse challenges but also enable me to excel in roles that require a blend of technical proficiency and effective interpersonal skills. Whether I'm pursuing a career in technology, data analysis, management, or consulting, these skills will help me stay relevant, solve complex problems, and communicate effectively, positioning me as a valuable asset in any field.
#
# 8.2
# Becoming a statistician or data scientist without coding or data analysis experience would be quite challenging. Both fields heavily rely on coding and data analysis skills. Here's why:
#
# ### **Statistician:**
# - **Data Analysis:** Statisticians analyze and interpret data to make informed decisions and predictions. This requires strong analytical skills and familiarity with statistical methods.
# - **Coding:** Many statistical tasks involve using software tools and programming languages (like R or Python) to perform analyses, manage data, and automate tasks. Coding is often essential for handling complex data sets and implementing advanced statistical techniques.
#
# ### **Data Scientist:**
# - **Data Analysis:** Data scientists extract insights from large and complex data sets, requiring proficiency in data manipulation and statistical analysis.
# - **Coding:** Coding is crucial for data cleaning, analysis, and building predictive models. Data scientists often use programming languages (such as Python or SQL) to work with data, develop algorithms, and create visualizations.
#
# ### **Alternatives:**
# - **Learning Coding and Data Analysis:** If you're interested in these fields, gaining experience in coding and data analysis can open up opportunities. There are many resources, including online courses and bootcamps, that can help you acquire these skills.
# - **Complementary Roles:** If coding and data analysis aren't your strengths, you might consider roles that leverage other skills, such as project management, business analysis, or client-facing positions in the data domain.
#
# In summary, while coding and data analysis are integral to statisticians and data scientists, developing these skills would greatly enhance your ability to succeed in these careers.
#
# If I want to  a statistician or data scientist , what is the core skill I need?
#
# To become a statistician or data scientist, you'll need a strong foundation in several core skills. Here’s a breakdown of the essential skills for each role:
#
# ### **Core Skills for a Statistician:**
#
# 1. **Statistical Knowledge:**
#    - **Understanding of Statistical Methods:** Proficiency in hypothesis testing, regression analysis, probability theory, and experimental design.
#    - **Statistical Software:** Familiarity with tools like R, SAS, or SPSS for performing statistical analyses.
#
# 2. **Data Analysis:**
#    - **Data Interpretation:** Ability to analyze and interpret data to draw meaningful conclusions.
#    - **Data Cleaning:** Skills in cleaning and preparing data for analysis.
#
# 3. **Mathematics:**
#    - **Advanced Mathematics:** Strong background in mathematics, including calculus and linear algebra, as it underpins many statistical methods.
#
# 4. **Communication:**
#    - **Reporting Results:** Ability to present complex statistical findings in a clear and understandable manner, both in writing and verbally.
#
# ### **Core Skills for a Data Scientist:**
#
# 1. **Coding and Programming:**
#    - **Programming Languages:** Proficiency in languages such as Python, R, or SQL for data manipulation, analysis, and automation.
#    - **Data Manipulation:** Skills in using libraries and frameworks for data processing (e.g., pandas, NumPy).
#
# 2. **Data Analysis and Machine Learning:**
#    - **Statistical and Analytical Skills:** Knowledge of statistical techniques and data analysis methods.
#    - **Machine Learning:** Understanding of machine learning algorithms and techniques for building predictive models.
#
# 3. **Data Visualization:**
#    - **Visualization Tools:** Ability to create visual representations of data using tools like Matplotlib, Seaborn, or Tableau.
#
# 4. **Mathematics and Statistics:**
#    - **Foundational Knowledge:** Strong background in mathematics and statistics, as these are fundamental to developing and understanding models and algorithms.
#
# 5. **Communication:**
#    - **Insights Presentation:** Skills to convey complex data insights to non-technical stakeholders in a clear and actionable way.
#
# ### **Summary**
#
# For both roles, **strong analytical skills** and a solid understanding of **statistical methods** are crucial. **Data analysis** is at the heart of both professions, but data scientists additionally need strong **coding skills** and knowledge of **machine learning**. Effective **communication** skills are also essential for both roles to explain findings and insights to various audiences. Developing proficiency in these core areas will be key to succeeding as a statistician or data scientist.
#
#
# 8.3
#
# Here’s a summary of our conversation so far:
#
# 1. **Markovian Chatbot Models:**
#    - We discussed various extensions of a Markov model for a chatbot, including basic bigram models and character-specific models.
#    - Extension #1 used bigrams to track word pairs and their following words.
#    - Extension #2 added a character dimension, tracking bigrams and their subsequent words for different characters in a dataset.
#
# 2. **Career Opportunities:**
#    - We explored how skills in learning and adaptability, communication, coding, and statistics can enhance career opportunities.
#    - Each skill contributes to versatility, effective problem-solving, and strong professional communication.
#
# 3. **Becoming a Statistician or Data Scientist:**
#    - We discussed the core skills required for these roles. Statisticians need strong statistical knowledge, data analysis skills, and proficiency in statistical software. Data scientists need coding skills, expertise in data analysis and machine learning, data visualization abilities, and strong mathematical and statistical knowledge.
#
# In summary, the conversation focused on enhancing chatbot models, leveraging key skills for career growth, and the essential skills needed for roles in statistics and data science.
#
# chat summary: https://chatgpt.com/share/66eb7693-6f90-8008-b647-ef950293106e
#
# 8.4
# I would like to major in math or statistics in the future, which may require me to study coding and statistics. I may also specialize in math in the future. It depends on my interest and my ability of learning. But there will always be no escape from statistics and math. I don't think I can become a researcher or scientist in these fields, but I want to work on related jobs. I would like to use what I've learned in college in my work, which would help me adapt faster to jobs. I hope the things I learned in college could help me specifically in my life and work, not just broadening my eyesights.
#
# 8.5
# I would say chatgpt gives me a relatively deep explanation for the code or question I provide. When I ask it with some basic functions in python, it will explain in a beginner-friendly way, giving me examples to help me understand. And for the code I want it to explain, I think it might answer too general. I need to narrow down every line of my code to ask it how the codes work. It just gives me a brief explanation, which is less helpful. In general, the explanation the chat gives is readable. But for some cpmlex codes, I don't think it could explain better than my teachers or classmates. This might because chat does not know the level of my understanding of python. It just give general explanation.
#
# 9.
# no
